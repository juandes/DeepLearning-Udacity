# %% [markdown]
# Deep Learning
# =============
#
# Assignment 4
# ------------
#
# Previously in `2_fullyconnected.ipynb` and `3_regularization.ipynb`, we trained fully connected networks to classify [notMNIST](http://yaroslavvb.blogspot.com/2011/09/notmnist-dataset.html) characters.
#
# The goal of this assignment is make the neural network convolutional.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import numpy as np
import tensorflow as tf
from six.moves import cPickle as pickle
from six.moves import range

# %%
pickle_file = 'notMNIST.pickle'

with open(pickle_file, 'rb') as f:
  save = pickle.load(f)
  train_dataset = save['train_dataset']
  train_labels = save['train_labels']
  valid_dataset = save['valid_dataset']
  valid_labels = save['valid_labels']
  test_dataset = save['test_dataset']
  test_labels = save['test_labels']
  del save  # hint to help gc free up memory
  print('Training set', train_dataset.shape, train_labels.shape)
  print('Validation set', valid_dataset.shape, valid_labels.shape)
  print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28) (200000,)
# Validation set (10000, 28, 28) (10000,)
# Test set (10000, 28, 28) (10000,)

# %% [markdown]
# Reformat into a TensorFlow-friendly shape:
# - convolutions need the image data formatted as a cube (width by height by #channels)
# - labels as float 1-hot encodings.

# %%
image_size = 28
num_labels = 10
num_channels = 1 # grayscale

import numpy as np

def reformat(dataset, labels):
  dataset = dataset.reshape(
    (-1, image_size, image_size, num_channels)).astype(np.float32)
  labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
  return dataset, labels
train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)
print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28, 1) (200000, 10)
# Validation set (10000, 28, 28, 1) (10000, 10)
# Test set (10000, 28, 28, 1) (10000, 10)

# %%
def accuracy(predictions, labels):
  return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
          / predictions.shape[0])

# %% [markdown]
# Let's build a small network with two convolutional layers, followed by one fully connected layer. Convolutional networks are more expensive computationally, so we'll limit its depth and number of fully connected nodes.

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    conv = tf.nn.conv2d(hidden, layer2_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 2.980103
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 1.389038
# Minibatch accuracy: 37.5%
# Validation accuracy: 41.8%
# Minibatch loss at step 100: 0.530993
# Minibatch accuracy: 87.5%
# Validation accuracy: 51.9%
# Minibatch loss at step 150: 1.088284
# Minibatch accuracy: 68.8%
# Validation accuracy: 56.0%
# Minibatch loss at step 200: 0.851492
# Minibatch accuracy: 75.0%
# Validation accuracy: 60.0%
# Minibatch loss at step 250: 1.068199
# Minibatch accuracy: 62.5%
# Validation accuracy: 59.2%
# Minibatch loss at step 300: 0.519525
# Minibatch accuracy: 81.2%
# Validation accuracy: 63.2%
# Minibatch loss at step 350: 0.217383
# Minibatch accuracy: 93.8%
# Validation accuracy: 61.4%
# Minibatch loss at step 400: 0.643047
# Minibatch accuracy: 81.2%
# Validation accuracy: 64.0%
# Minibatch loss at step 450: 0.768113
# Minibatch accuracy: 75.0%
# Validation accuracy: 64.1%
# Minibatch loss at step 500: 0.776809
# Minibatch accuracy: 81.2%
# Validation accuracy: 64.1%
# Minibatch loss at step 550: 0.638092
# Minibatch accuracy: 81.2%
# Validation accuracy: 65.7%
# Minibatch loss at step 600: 0.681112
# Minibatch accuracy: 75.0%
# Validation accuracy: 65.1%
# Minibatch loss at step 650: 0.502857
# Minibatch accuracy: 87.5%
# Validation accuracy: 65.1%
# Minibatch loss at step 700: 0.513226
# Minibatch accuracy: 87.5%
# Validation accuracy: 67.4%
# Minibatch loss at step 750: 0.369606
# Minibatch accuracy: 87.5%
# Validation accuracy: 66.7%
# Minibatch loss at step 800: 0.905138
# Minibatch accuracy: 68.8%
# Validation accuracy: 64.6%
# Minibatch loss at step 850: 0.634651
# Minibatch accuracy: 81.2%
# Validation accuracy: 67.3%
# Minibatch loss at step 900: 0.769973
# Minibatch accuracy: 81.2%
# Validation accuracy: 66.5%
# Minibatch loss at step 950: 0.203813
# Minibatch accuracy: 93.8%
# Validation accuracy: 67.2%
# Minibatch loss at step 1000: 0.850664
# Minibatch accuracy: 75.0%
# Validation accuracy: 66.3%
# Test accuracy: 88.4%

# %% [markdown]
# ---
# Problem 1
# ---------
#
# The convolutional model above uses convolutions with stride 2 to reduce the dimensionality. Replace the strides by a max pooling operation (`nn.max_pool()`) of stride 2 and kernel size 2.
#
# ---

# %%
# PREPARATION STEP
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    pool1 = tf.nn.max_pool(hidden, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
    conv = tf.nn.conv2d(pool1, layer2_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    pool2 = tf.nn.max_pool(hidden, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
    shape = pool2.get_shape().as_list()
    reshape = tf.reshape(pool2, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 4.079098
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 1.933846
# Minibatch accuracy: 31.2%
# Validation accuracy: 34.5%
# Minibatch loss at step 100: 0.822528
# Minibatch accuracy: 81.2%
# Validation accuracy: 50.4%
# Minibatch loss at step 150: 0.963091
# Minibatch accuracy: 68.8%
# Validation accuracy: 55.9%
# Minibatch loss at step 200: 0.874845
# Minibatch accuracy: 68.8%
# Validation accuracy: 58.9%
# Minibatch loss at step 250: 0.838696
# Minibatch accuracy: 75.0%
# Validation accuracy: 61.1%
# Minibatch loss at step 300: 0.237653
# Minibatch accuracy: 100.0%
# Validation accuracy: 63.5%
# Minibatch loss at step 350: 0.175043
# Minibatch accuracy: 93.8%
# Validation accuracy: 61.7%
# Minibatch loss at step 400: 0.445050
# Minibatch accuracy: 87.5%
# Validation accuracy: 63.1%
# Minibatch loss at step 450: 0.678714
# Minibatch accuracy: 75.0%
# Validation accuracy: 63.8%
# Minibatch loss at step 500: 0.787111
# Minibatch accuracy: 75.0%
# Validation accuracy: 66.0%
# Minibatch loss at step 550: 0.772662
# Minibatch accuracy: 75.0%
# Validation accuracy: 66.0%
# Minibatch loss at step 600: 0.578707
# Minibatch accuracy: 87.5%
# Validation accuracy: 68.4%
# Minibatch loss at step 650: 0.436093
# Minibatch accuracy: 87.5%
# Validation accuracy: 68.5%
# Minibatch loss at step 700: 0.493237
# Minibatch accuracy: 81.2%
# Validation accuracy: 68.8%
# Minibatch loss at step 750: 0.461447
# Minibatch accuracy: 87.5%
# Validation accuracy: 69.0%
# Minibatch loss at step 800: 0.687347
# Minibatch accuracy: 68.8%
# Validation accuracy: 66.3%
# Minibatch loss at step 850: 0.537705
# Minibatch accuracy: 81.2%
# Validation accuracy: 69.5%
# Minibatch loss at step 900: 0.731626
# Minibatch accuracy: 87.5%
# Validation accuracy: 68.8%
# Minibatch loss at step 950: 0.173733
# Minibatch accuracy: 93.8%
# Validation accuracy: 68.0%
# Minibatch loss at step 1000: 0.880124
# Minibatch accuracy: 75.0%
# Validation accuracy: 69.8%
# Test accuracy: 90.2%

# %% [markdown]
# ---
# Problem 2
# ---------
#
# Try to get the best performance you can using a convolutional net. Look for example at the classic [LeNet5](http://yann.lecun.com/exdb/lenet/) architecture, adding Dropout, and/or adding learning rate decay.
#
# ---

# %%
# PREPARATION STEP
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  size3 = ((image_size - patch_size + 1) // 2 - patch_size + 1) // 2
  layer3_weights = tf.Variable(tf.truncated_normal(
      [size3 * size3 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_hidden], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer5_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer5_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='VALID')
    hidden = tf.nn.relu(conv + layer1_biases)
    pool = tf.nn.max_pool(hidden, [1, 2, 2, 1], [1, 2, 2, 1], padding='VALID')
    conv = tf.nn.conv2d(pool, layer2_weights, [1, 1, 1, 1], padding='VALID')
    hidden = tf.nn.relu(conv + layer2_biases)
    pool = tf.nn.max_pool(hidden, [1, 2, 2, 1], [1, 2, 2, 1], padding='VALID')
    shape = pool.get_shape().as_list()
    reshape = tf.reshape(pool, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    hidden = tf.nn.relu(tf.matmul(hidden, layer4_weights) + layer4_biases)
    drop = tf.nn.dropout(hidden, 0.5)
    return tf.matmul(hidden, layer5_weights) + layer5_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 3001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 2.325814
# Minibatch accuracy: 0.0%
# Validation accuracy: 9.7%
# Minibatch loss at step 50: 1.968193
# Minibatch accuracy: 31.2%
# Validation accuracy: 29.4%
# Minibatch loss at step 100: 1.100391
# Minibatch accuracy: 62.5%
# Validation accuracy: 32.6%
# Minibatch loss at step 150: 1.242904
# Minibatch accuracy: 62.5%
# Validation accuracy: 46.0%
# Minibatch loss at step 200: 0.757166
# Minibatch accuracy: 81.2%
# Validation accuracy: 51.5%
# Minibatch loss at step 250: 1.262908
# Minibatch accuracy: 62.5%
# Validation accuracy: 59.1%
# Minibatch loss at step 300: 0.325294
# Minibatch accuracy: 93.8%
# Validation accuracy: 60.6%
# Minibatch loss at step 350: 0.388686
# Minibatch accuracy: 93.8%
# Validation accuracy: 60.8%
# Minibatch loss at step 400: 0.464950
# Minibatch accuracy: 87.5%
# Validation accuracy: 59.9%
# Minibatch loss at step 450: 0.802051
# Minibatch accuracy: 75.0%
# Validation accuracy: 61.6%
# Minibatch loss at step 500: 0.823263
# Minibatch accuracy: 81.2%
# Validation accuracy: 62.5%
# Minibatch loss at step 550: 0.966193
# Minibatch accuracy: 62.5%
# Validation accuracy: 61.2%
# Minibatch loss at step 600: 0.407384
# Minibatch accuracy: 87.5%
# Validation accuracy: 65.4%
# Minibatch loss at step 650: 0.493706
# Minibatch accuracy: 87.5%
# Validation accuracy: 65.6%
# Minibatch loss at step 700: 0.663048
# Minibatch accuracy: 81.2%
# Validation accuracy: 65.7%
# Minibatch loss at step 750: 0.356395
# Minibatch accuracy: 87.5%
# Validation accuracy: 65.4%
# Minibatch loss at step 800: 0.933294
# Minibatch accuracy: 75.0%
# Validation accuracy: 63.9%
# Minibatch loss at step 850: 0.342458
# Minibatch accuracy: 93.8%
# Validation accuracy: 66.4%
# Minibatch loss at step 900: 0.854498
# Minibatch accuracy: 87.5%
# Validation accuracy: 66.6%
# Minibatch loss at step 950: 0.416355
# Minibatch accuracy: 93.8%
# Validation accuracy: 61.4%
# Minibatch loss at step 1000: 0.868393
# Minibatch accuracy: 68.8%
# Validation accuracy: 65.0%
# Minibatch loss at step 1050: 0.743742
# Minibatch accuracy: 75.0%
# Validation accuracy: 66.5%
# Minibatch loss at step 1100: 0.872444
# Minibatch accuracy: 81.2%
# Validation accuracy: 67.1%
# Minibatch loss at step 1150: 0.099866
# Minibatch accuracy: 100.0%
# Validation accuracy: 67.0%
# Minibatch loss at step 1200: 0.182114
# Minibatch accuracy: 93.8%
# Validation accuracy: 67.5%
# Minibatch loss at step 1250: 1.029192
# Minibatch accuracy: 75.0%
# Validation accuracy: 68.4%
# Minibatch loss at step 1300: 0.445030
# Minibatch accuracy: 93.8%
# Validation accuracy: 69.5%
# Minibatch loss at step 1350: 0.347751
# Minibatch accuracy: 87.5%
# Validation accuracy: 69.2%
# Minibatch loss at step 1400: 0.878801
# Minibatch accuracy: 75.0%
# Validation accuracy: 69.1%
# Minibatch loss at step 1450: 0.274831
# Minibatch accuracy: 93.8%
# Validation accuracy: 70.4%
# Minibatch loss at step 1500: 0.345906
# Minibatch accuracy: 93.8%
# Validation accuracy: 69.2%
# Minibatch loss at step 1550: 0.235856
# Minibatch accuracy: 93.8%
# Validation accuracy: 68.6%
# Minibatch loss at step 1600: 1.005048
# Minibatch accuracy: 68.8%
# Validation accuracy: 68.8%
# Minibatch loss at step 1650: 0.368337
# Minibatch accuracy: 87.5%
# Validation accuracy: 68.0%
# Minibatch loss at step 1700: 0.876602
# Minibatch accuracy: 75.0%
# Validation accuracy: 70.2%
# Minibatch loss at step 1750: 0.190769
# Minibatch accuracy: 87.5%
# Validation accuracy: 71.8%
# Minibatch loss at step 1800: 0.577744
# Minibatch accuracy: 81.2%
# Validation accuracy: 69.7%
# Minibatch loss at step 1850: 0.006592
# Minibatch accuracy: 100.0%
# Validation accuracy: 71.7%
# Minibatch loss at step 1900: 0.547866
# Minibatch accuracy: 75.0%
# Validation accuracy: 72.1%
# Minibatch loss at step 1950: 0.433722
# Minibatch accuracy: 87.5%
# Validation accuracy: 72.0%
# Minibatch loss at step 2000: 1.210205
# Minibatch accuracy: 68.8%
# Validation accuracy: 70.2%
# Minibatch loss at step 2050: 0.466902
# Minibatch accuracy: 81.2%
# Validation accuracy: 71.2%
# Minibatch loss at step 2100: 0.426223
# Minibatch accuracy: 81.2%
# Validation accuracy: 70.9%
# Minibatch loss at step 2150: 0.332418
# Minibatch accuracy: 81.2%
# Validation accuracy: 71.5%
# Minibatch loss at step 2200: 0.594576
# Minibatch accuracy: 87.5%
# Validation accuracy: 71.5%
# Minibatch loss at step 2250: 0.685003
# Minibatch accuracy: 87.5%
# Validation accuracy: 71.8%
# Minibatch loss at step 2300: 0.166016
# Minibatch accuracy: 100.0%
# Validation accuracy: 71.5%
# Minibatch loss at step 2350: 0.421921
# Minibatch accuracy: 87.5%
# Validation accuracy: 70.5%
# Minibatch loss at step 2400: 0.488436
# Minibatch accuracy: 81.2%
# Validation accuracy: 71.4%
# Minibatch loss at step 2450: 0.524887
# Minibatch accuracy: 81.2%
# Validation accuracy: 70.7%
# Minibatch loss at step 2500: 0.132687
# Minibatch accuracy: 100.0%
# Validation accuracy: 73.0%
# Minibatch loss at step 2550: 0.545102
# Minibatch accuracy: 75.0%
# Validation accuracy: 72.0%
# Minibatch loss at step 2600: 0.147148
# Minibatch accuracy: 93.8%
# Validation accuracy: 72.0%
# Minibatch loss at step 2650: 0.123854
# Minibatch accuracy: 100.0%
# Validation accuracy: 72.8%
# Minibatch loss at step 2700: 0.932362
# Minibatch accuracy: 75.0%
# Validation accuracy: 73.2%
# Minibatch loss at step 2750: 0.277718
# Minibatch accuracy: 93.8%
# Validation accuracy: 73.0%
# Minibatch loss at step 2800: 0.378278
# Minibatch accuracy: 93.8%
# Validation accuracy: 72.6%
# Minibatch loss at step 2850: 0.806113
# Minibatch accuracy: 75.0%
# Validation accuracy: 74.0%
# Minibatch loss at step 2900: 0.478879
# Minibatch accuracy: 87.5%
# Validation accuracy: 71.7%
# Minibatch loss at step 2950: 0.566024
# Minibatch accuracy: 81.2%
# Validation accuracy: 73.1%
# Minibatch loss at step 3000: 0.249453
# Minibatch accuracy: 93.8%
# Validation accuracy: 72.9%
# Test accuracy: 92.4%
